# %%
# <html>
# <head>
# <link rel="stylesheet" href="https://pyscript.net/alpha/pyscript.css" />
# <script defer src="https://pyscript.net/alpha/pyscript.js"></script>
# </head>


# <body>
# <py-script>
#     print("Minha primeira pagina html")
# </py-script>

# <py-script>
#     from datetime import datetime
#     faturamento = 1000
#     custo = 700
#     lucro = faturamento - custo
#     data_atualizacao = datetime.now()
#     print(f"Lucro apurado: R${lucro}")
#     print(f"Atualizado em: {data_atualizacao}")
# </py-script>
# </body>

# </html>

# %%
import pandas as pd
import json
import requests
from io import StringIO
#link = 'https://api.bcb.gov.br/dados/serie/bcdata.sgs.22711/dados?formato=json'
link = 'https://github.com/kaiohas/py-treinamento-hashtag/raw/refs/heads/main/powerbi/Contoso%20-%20Lojas.csv'
requisicao = requests.get(link)
#informacoes = requisicao.json()
csv_data = StringIO(requisicao.text)
df = pd.read_csv(csv_data,sep=';')
df
# Out:
#      ÿID Loja                         Nome da Loja  Quantidade Colaboradores  \
# 0           1           Loja Contoso Seattle No.1                       17.0
# 1           2           Loja Contoso Seattle No.2                       25.0
# 2           3              Loja Contoso Kennewick                       26.0
# 3           4               Loja Contoso Bellevue                       19.0
# 4           5                Loja Contoso Redmond                       33.0
# ..        ...                                  ...                       ...
# 301       306          Loja Contoso Europe Online                        7.0
# 302       307            Loja Contoso Asia Online                        8.0
# 303       308  Loja Contoso North America Reseller                      15.0
# 304       309         Loja Contoso Europe Reseller                      12.0
# 305       310           Loja Contoso Asia Reseller                      17.0
#
#                País
# 0    Estados Unidos
# ...
