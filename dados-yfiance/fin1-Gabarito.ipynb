# %% [markdown]
# ###  Python e Finanças
#
# Bibliotecas mais usadas:
#
# - pandas
# - matplotlib
# - numpy
# - datetime
#
# Vamos usar também ferramentas para puxar cotações e afins:
#
# - pandas_datareader
# - yfinance

# %%
# !pip install pandas-datareader
# !pip install yfinance
# Out:
# Requirement already satisfied: pandas-datareader in c:\users\joaol\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\joaol\anaconda3\lib\site-packages (from pandas-datareader) (2.31.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\joaol\anaconda3\lib\site-packages (from pandas-datareader) (2.0.3)
# Requirement already satisfied: lxml in c:\users\joaol\anaconda3\lib\site-packages (from pandas-datareader) (4.9.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joaol\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\joaol\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\joaol\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.23.5)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\joaol\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2023.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joaol\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\joaol\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joaol\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joaol\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.4)
# Requirement already satisfied: six>=1.5 in c:\users\joaol\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.16.0)
# Requirement already satisfied: yfinance in c:\users\joaol\anaconda3\lib\site-packages (0.2.27)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\joaol\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\joaol\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\joaol\anaconda3\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\joaol\anaconda3\lib\site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\joaol\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: requests>=2.31 in c:\users\joaol\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\joaol\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\joaol\anaconda3\lib\site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: pytz>=2022.5 in c:\users\joaol\anaconda3\lib\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\joaol\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\joaol\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\joaol\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\joaol\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\joaol\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\joaol\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joaol\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\joaol\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joaol\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joaol\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2022.12.7)

# %% [markdown]
# #### Referências:
# - Índices:
#
# ^INDICE -> exemplo: ^BVSP (BOVESPA)
#
# - Ações BR:
#
# TICKER.SA -> exemplo: ITUB4.SA (ação ITUB4 da bolsa brasileira)
#
# - Ações Internacionais:
#
# TICKER -> exemplo: GOOG (ação do google na bolsa americana)

# %% [markdown]
# #### Analisando o IBOV

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import pandas_datareader.data as pdr
import yfinance

yfinance.pdr_override()

# %%
data_inicial = datetime.now() - timedelta(days=360)
data_final = datetime.now()

df_ibov = pdr.get_data_yahoo("^BVSP", data_inicial, data_final)["Adj Close"]
display(df_ibov)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2022-08-15    113032.000000
# 2022-08-16    113512.000000
# 2022-08-17    113708.000000
# 2022-08-18    113813.000000
# 2022-08-19    111496.000000
#                   ...
# 2023-08-02    120859.000000
# 2023-08-03    120586.000000
# 2023-08-04    119508.000000
# 2023-08-07    119380.000000
# 2023-08-08    119090.242188
# Name: Adj Close, Length: 246, dtype: float64

# %% [markdown]
# #### Analisando o Gráfico

# %%
df_ibov.plot()
plt.show()

# %% [markdown]
# #### Retorno do IBOV

# %%
retorno_ibov = df_ibov.iloc[-1] / df_ibov.iloc[0] - 1
print(f"O retorno do IBOV foi: {retorno_ibov:.1%}")
# Out:
# O retorno do IBOV foi: 5.4%

# %% [markdown]
# #### Média Móvel

# %%
df_ibov.plot(label="IBOV")
media_movel = df_ibov.rolling(21).mean()
media_movel.plot(label="MM21")
plt.legend()
plt.show()
